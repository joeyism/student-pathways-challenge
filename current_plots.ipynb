# %%
from util.load_all_csv import load_all_csv
import matplotlib.pyplot as plt
# %pylab inline
pylab.rcParams['figure.figsize'] = (8, 4)
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dfs = load_all_csv()

# %% [markdown]
# # Number of jobs available per skill, for all levels
# ### Data Analysis
# The collection and analysis of data in numberical form
#
# ### Decision Making
# Making a choice among options using appropriate information.
#
# ### Finding Information
# The use of a variety of sources, including written text, people, computerized databases, and information systems.
#
# ### Job Task Planning and Organizing
# The planning and organization of one's own work.
#
# ### Measurement and Calculation
# The measurement and calculation of quantities, areas, volumes, and/or distances.
#
# ### Money Math
# The use of mathematical skills in making financial transactions, such as handling cash, preparing bills, and making payments.
#
# ### Numerical Estimation
# The production of estimates in numerical terms.
#
# ### Oral Communication
# Using verbal skills to exchange ideas and information with others.
#
# ### Problem Solving
# The identification and solving of problems.
#
# ### Reading
# Reading materials in the form of sentences or paragraphs such as notes, letters, memos, manuals, specifications, books, reports and journals.
#
# ### Scheduling or Budgeting and Accounting
# Planning for the best use of time and money, as well as monitoring of the use of time and money.
#
# ### Digital Technology
# The use of any type of digital technology
#
# ### Document Use
# Reading different types of material such as labels, signs, lists, tables, graphs, forms, diagrams, blueprints and other similar material.
#
# ### Writing
# The preparation of written materials for a variety of purposes. Completing such tasks as filling in forms, writing text and using computers to write.
#
# ### Critical Thinking
# Making judgments by using criteria to evaluate ideas and information and the related consequences.

# %%
_ = dfs.plot_essential_skills()
# Out:
# './Labour_Market/Essential-Skills-Comp\x82tences-Cl\x82s/Essential-Skills.csv'

# %% [markdown]
# # Number of tasks in jobs available per skill level
# Essentially, this is a breakdown of the plot above, with which are done by people with specific education

# %%
_ = dfs.plot_no_skill_jobs_per_education_level()
# Out:
# './Labour_Market/Essential-Skills-Comp\x82tences-Cl\x82s/Essential-Skills.csv'

# %% [markdown]
# # Program Ranking
# This describes which programs applicants put 1st - 4th choice, whether their acceptance has been confirmed or not.

# %%
_ = dfs.plot_program_ranking()
# Out:
# './Application_and_Enrolment/Applications-by-University-Program/Applications-by-University-Program.csv'

# %% [markdown]
# For applicants that has their admittance confirmed

# %%
_ = dfs.plot_program_ranking(year='16-17', confirmed=True)
# Out:
# './Application_and_Enrolment/Applications-by-University-Program/Applications-by-University-Program.csv'

# %% [markdown]
# For applicants that does not have their admittance confirmed

# %%
_ = dfs.plot_program_ranking(year='16-17', confirmed=False)
# Out:
# './Application_and_Enrolment/Applications-by-University-Program/Applications-by-University-Program.csv'

# %% [markdown]
# # How surveyed education and their work is related

# %%
_ = dfs.plot_university_degree_job_relatedness()
# Out:
# './Employment/University-Degree-Job-Relatedness/University-Degree-Job-Relatedness.csv'

# %% [markdown]
# # Which university has better employment?
# For Engineering, after 6 months, the graph below shows the percentage of people employed. Program can be changed to the various programs, and the data can switch between 6 months and 24 months.
#
# ### Program Names
# ABS	Agricultural & Bio. Sciences
# ALA	Architecture & Landscape Arch.
# BCO	Business & Commerce
# CSC	Computer Science
# DEN	Dentistry
# EDU	Education
# ENG	Engineering
# FAA	Fine & Applied Arts
# FOR	Forestry
# FSN	Food Science & Nutrition
# HPR	Health Professions
# HUM	Humanities
# JOU	Journalism
# KRP	Kinesiology/Recreation/Phys-Ed
# LAW	Law
# MAT	Mathematics
# MED	Medicine
# NUR	Nursing
# OAS	Other Arts & Science
# OPT	Optometry
# PHA	Pharmacy
# PSC	Physical Sciences
# SSC	Social Sciences
# THE	Theology
# TRE	Therapy & Rehabilitation
# VME	Veterinary Medicine
#
# ### Universities
#
# ALG	Algoma
# BRO	Brock
# CAR	Carleton
# GUE	Guelph
# HEA	Hearst
# LAK	Lakehead
# LAU	Laurentian
# MCM	McMaster
# NIP	Nipissing
# OCA	OCADU
# OTT	Ottawa
# QUE	Queens
# RYE	Ryerson
# TOR	Toronto
# TRE	Trent
# UOI	UOIT
# WAT	Waterloo
# WES	Western
# WIN	Windsor
# WLA	Wilfrid Laurier
# YOR	York

# %%
_ = dfs.plot_university_employment_rates(program="ENG", period="6")
_ = dfs.plot_university_employment_rates(program="ENG", period="24")
_ = dfs.plot_university_employment_rates(program="HUM", period="6")
# Out:
# './Employment/University-Employment-Rates/University-Employment-Rates.csv'
